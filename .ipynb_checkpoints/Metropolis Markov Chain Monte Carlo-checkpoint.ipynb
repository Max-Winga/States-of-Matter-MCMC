# %%
import numpy as np
import math as m
from matplotlib import pyplot as plt
import random as r

# %%
class Metropolis():
    
    def __init__(self, size, T=1, initial_state=0):
        if initial_state==0:
            self.grid = np.ones(size)
        else:
            self.grid = initial_state
        self.size = size
        self.T = T
        self.B = 1/T
        self.energy_history = []
    
    def run(self, n, to_print=False):
        e1 = self.calc_energy()
        self.energy_history.append(e1)
        for i in range(n):
            x = np.random.randint(0, self.size[1])
            y = np.random.randint(0, self.size[0])
            self.grid[y, x] = self.grid[y, x]*-1
            e2 = self.calc_energy()
            self.energy_history.append(e2)
            if to_print: print(f"e1 = {e1}, e2 = {e2}")
            prob = m.exp(-self.B*(e2-e1))
            if to_print: print(f"prob = {prob}")
            if r.random() > prob:
                if to_print: print("Rejected")
                self.grid[y, x] = self.grid[y, x]*-1
                continue
            if to_print: print("Accepted")
            e1 = e2
        return
            
    def calc_energy(self, grid=0):
        if type(grid) == int: grid = self.grid
        energy = 0
        vbonds = self.build_vbond_array(grid)
        hbonds = self.build_hbond_array(grid)
        for y in range(self.size[0]):
            for x in range(self.size[1]):
                energy += vbonds[y, x] + hbonds[y, x]
        return energy
    
    def build_vbond_array(self, grid=0):
        if type(grid) == int: grid = self.grid
        vbond_array = np.zeros(self.size)
        for x in range(self.size[1]):
            vbond_array[0, x] = -self.grid[0,x]*self.grid[self.size[0]-1, x]
        for y in range(1, self.size[0]):
            for x in range(self.size[1]):
                vbond_array[y, x] = -self.grid[y,x]*self.grid[y-1, x]
        return vbond_array
    
    def build_hbond_array(self, grid=0):
        if type(grid) == int: grid = self.grid
        hbond_array = np.zeros(self.size)
        for y in range(self.size[0]):
            hbond_array[y, 0] = -self.grid[y,0]*self.grid[y, self.size[1]-1]
        for y in range(self.size[0]):
            for x in range(1, self.size[1]):
                hbond_array[y, x] = -self.grid[y,x]*self.grid[y, x-1]
        return hbond_array
        
    def flip_bit(self, bit):
        bit = int(bit)
        if bit == 0:
            return 1
        return 0
    
    def get_grid(self):
        return self.grid
    
    def get_energy_history(self):
        return self.energy_history

# %%
test_metro = Metropolis([3, 3], T = 3)
print(test_metro.calc_energy())
plt.figure()
plt.matshow(test_metro.get_grid())
plt.show()

test_metro.run(10000, to_print=True)
print(test_metro.calc_energy())
plt.figure()
plt.matshow(test_metro.get_grid())
plt.show()
# Out:
# -18.0
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Accepted
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Accepted
# e1 = 6.0, e2 = 6.0
# prob = 1.0
# Accepted
# e1 = 6.0, e2 = 6.0
# prob = 1.0
# Accepted
# e1 = 6.0, e2 = 2.0
# prob = 3.7936678946831774
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Accepted
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -6.0
# prob = 14.391916095149892
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = -6.0
# prob = 14.391916095149892
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# ...
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Accepted
# e1 = 6.0, e2 = 2.0
# prob = 3.7936678946831774
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Accepted
# e1 = 6.0, e2 = 6.0
# prob = 1.0
# Accepted
# e1 = 6.0, e2 = 6.0
# prob = 1.0
# Accepted
# e1 = 6.0, e2 = -2.0
# prob = 14.391916095149892
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -10.0
# prob = 14.391916095149892
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 6.0
# prob = 0.26359713811572677
# Rejected
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = -2.0
# prob = 3.7936678946831774
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -6.0
# prob = 1.0
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Accepted
# e1 = 2.0, e2 = 2.0
# prob = 1.0
# Accepted
# e1 = 2.0, e2 = -6.0
# prob = 14.391916095149892
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Rejected
# e1 = -18.0, e2 = -10.0
# prob = 0.06948345122280154
# Accepted
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = 6.0
# prob = 0.06948345122280154
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = 2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -2.0
# prob = 1.0
# Accepted
# e1 = -2.0, e2 = -6.0
# prob = 3.7936678946831774
# Accepted
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = -2.0
# prob = 0.26359713811572677
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = 2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -6.0, e2 = -10.0
# prob = 3.7936678946831774
# Accepted
# e1 = -10.0, e2 = -2.0
# prob = 0.06948345122280154
# Rejected
# e1 = -10.0, e2 = -6.0
# prob = 0.26359713811572677
# Rejected
# e1 = -10.0, e2 = -18.0
# prob = 14.391916095149892
# Accepted
# -18.0

# %%
energies = test_metro.get_energy_history()
print(len(energies))
plt.figure()
plt.plot(energies)
plt.show()
print(sum(energies[1000:])/len(energies[1000:]))
# Out:
# 10001
# -5.833351849794467

# %%
E_avgs = []
for T in np.arange(0, 20, 1):
    test_metro = Metropolis([9, 9], T = 2)
    test_metro.run(10000)
    energies = test_metro.get_energy_history()
    E_avg = sum(energies[1000:])/len(energies[1000:])
    E_avgs.append(E_avg)

# %%
plt.figure()
plt.plot(np.arange(0, 20, 1), E_avgs, color='r')
plt.title("Average E vs Temperature")
plt.xlabel("Temperature T")
plt.ylabel("Average Energy After 1st 100 Accepted Flips")
# Out:
# Text(0, 0.5, 'Average Energy After 1st 100 Accepted Flips')
